# %% [markdown]
# <a href="https://colab.research.google.com/github/eepsaranjan/Python/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temperatures = [34, 40, 29, 33, 42, 37, 39]
a=temperatures.index(max(temperatures))
b=temperatures.index(min(temperatures))
temperatures[a],temperatures[b]=temperatures[b],temperatures[a]
print(temperatures)
# Out:
# [34, 40, 42, 33, 29, 37, 39]

# %%
prod_price_list = [400, 250, 800, 550, 600, 820, 720, 15000, 360, 250]
n = len(prod_price_list)
mean = sum(prod_price_list) / n
print(mean)

prod_price_list=sorted(prod_price_list)
print(prod_price_list)
if n % 2 == 0: median=(prod_price_list[n//2]+prod_price_list[(n//2)-1])/2
else: median=prod_price_list[n//2]
print(median)
# Out:
# 1975.0
# [250, 250, 360, 400, 550, 600, 720, 800, 820, 15000]
# 575.0

# %%
tech_companies = ['Qualcomm', 'Google', 'Apple', ['Nvidia', 'Cisco', 'Samsung']]
tech_companies=tech_companies[:3]
tech_companies.extend(['Nvidia', 'Cisco', 'Samsung'])
print(tech_companies)
# Out:
# ['Qualcomm', 'Google', 'Apple', 'Nvidia', 'Cisco', 'Samsung']
