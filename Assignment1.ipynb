# %% [markdown]
# <a href="https://colab.research.google.com/github/eepsaranjan/Python/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation."
print(sentence.count(" ")+1)
# Out:
# 20

# %%
inputted_number = 10
print("-"*inputted_number)
# Out:
# ----------

# %%
bridge = 'rahul singh'
if bridge.find(" ")>0: print("Not Safe Bridge")
else: print("Safe Bridge")
# Out:
# Not Safe Bridge

# %%
user_string = 'Debris was scattered all over the place in the densest region of Denmark'
d=user_string.lower()
print(d.count('d'))
# Out:
# 4

# %%
user_string = 'madam'
if user_string[::-1]==user_string: print("True")
else: print("False")
# Out:
# True
